# %%
import pandas as pd

# %%
claustro=pd.read_csv("data\\claustro_n.csv")
ds=pd.read_csv("data\\listado_DS.csv")
fs=pd.read_csv("data\\listado_FS.csv")

# %%
intake=claustro[['Vertical','Campus','Fecha_promocion']].drop_duplicates()
intakenew=pd.DataFrame({'Vertical':['DS'],'Campus':['Madrid'],'Fecha_promocion':[202402]})
intake=pd.concat([intake,intakenew],ignore_index=True).sort_values(by='Fecha_promocion')
intake.insert(0,'Intake_id',range(1, len(intake) + 1))
intake
# Out:
#    Intake_id Vertical    Campus  Fecha_promocion
# 0          1       DS    Madrid           202309
# 1          2       FS    Madrid           202309
# 2          3       FS  Valencia           202309
# 3          4       FS  Valencia           202402
# 4          5       FS    Madrid           202402
# 5          6       DS    Madrid           202402

# %%
# intake.to_csv('intake.csv',index=False)

# %%
alumnos=pd.read_csv("alumnos.csv")
alumnos
# Out:
#     ID_Estudiante                Nombre                           Email  \
# 0               1          Jafet Casals          jafet_casals@gmail.com
# 1               2      Jorge Manzanares      jorge_manzanares@gmail.com
# 2               3         Onofre Adadia         onofre_adadia@gmail.com
# 3               4          Merche Prada          merche_prada@gmail.com
# 4               5          Pilar Abella          pilar_abella@gmail.com
# 5               6          Leoncio Tena          leoncio_tena@gmail.com
# 6               7       Odalys Torrijos       odalys_torrijos@gmail.com
# 7               8      Eduardo Caparrós      eduardo_caparrós@gmail.com
# 8               9    Ignacio Goicoechea    ignacio_goicoechea@gmail.com
# 9              10     Clementina Santos     clementina_santos@gmail.com
# 10             11         Daniela Falcó         daniela_falcó@gmail.com
# 11             12         Abraham Vélez         abraham_vélez@gmail.com
# ...

# %%
# alumnos.insert(0, 'Intake_id', list(range(1, len(alumnos) + 1)))
alumnos['Intake_id'][:15]=1
alumnos['Intake_id'][15:25]=6
alumnos['Intake_id'][25:39]=2
alumnos['Intake_id'][39:]=4
# Out:
# C:\Users\Agui\AppData\Local\Temp\ipykernel_17384\2015225013.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alumnos['Intake_id'][:15]=1
# C:\Users\Agui\AppData\Local\Temp\ipykernel_17384\2015225013.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   alumnos['Intake_id'][15:25]=6
# C:\Users\Agui\AppData\Local\Temp\ipykernel_17384\2015225013.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
alumnos.rename(columns={'Intake_id':'ID_Intake'},inplace=True)
# alumnos.to_csv('alumnos_intakeid.csv')

# %%
alumnos
# Out:
#     ID_Intake  ID_Estudiante                Nombre  \
# 0           1              1          Jafet Casals
# 1           1              2      Jorge Manzanares
# 2           1              3         Onofre Adadia
# 3           1              4          Merche Prada
# 4           1              5          Pilar Abella
# 5           1              6          Leoncio Tena
# 6           1              7       Odalys Torrijos
# 7           1              8      Eduardo Caparrós
# 8           1              9    Ignacio Goicoechea
# 9           1             10     Clementina Santos
# 10          1             11         Daniela Falcó
# 11          1             12         Abraham Vélez
# 12          1             13  Maximiliano Menéndez
# 13          1             14         Anita Heredia
# 14          1             15             Eli Casas
# 15          6             16     Guillermo Borrego
# 16          6             17        Sergio Aguirre
# ...

# %%
proyectosDS=alumnos[['ID_Intake','ID_Estudiante','Proyecto_HLF','Proyecto_EDA','Proyecto_BBDD','Proyecto_ML','Proyecto_Deployment']].dropna(axis=0)
proyectosFS=alumnos[['ID_Intake','ID_Estudiante','Proyecto_WebDev','Proyecto_FrontEnd','Proyecto_Backend','Proyecto_React','Proyecto_FullStack']].dropna(axis=0)

# %%
proyectosFS
# Out:
#     ID_Intake  ID_Estudiante Proyecto_WebDev Proyecto_FrontEnd  \
# 25          2             26            Apto              Apto
# 26          2             27         No Apto           No Apto
# 27          2             28            Apto           No Apto
# 28          2             29            Apto           No Apto
# 29          2             30            Apto              Apto
# 30          2             31         No Apto           No Apto
# 31          2             32         No Apto              Apto
# 32          2             33            Apto              Apto
# 33          2             34         No Apto              Apto
# 34          2             35         No Apto              Apto
# 35          2             36         No Apto              Apto
# 36          2             37            Apto              Apto
# 37          2             38            Apto              Apto
# 38          2             39            Apto              Apto
# ...

# %%
proyectosDS.insert(0, 'ID_calificacionesDS', list(range(1, len(proyectosDS) + 1)))
proyectosFS.insert(0, 'ID_calificacionesFS', list(range(1, len(proyectosFS) + 1)))

# %%
proyectosDS.to_csv('proyectosds.csv',index=False)
proyectosFS.to_csv('proyectosfs.csv',index=False)
